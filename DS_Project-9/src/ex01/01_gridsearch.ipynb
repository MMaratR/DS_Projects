# %% [markdown]
# # Day 09. Exercise 01
# # Gridsearch

# %% [markdown]
# ## 0. Imports

# %%
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm

# %%
from sklearn.model_selection import train_test_split, GridSearchCV, ParameterGrid, cross_val_score
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## 1. Preprocessing

# %% [markdown]
# 1. Прочитайте файл [`day-of-week-not-scaled.csv`](https://drive.google.com/file/d/1AlGvsJDSzPT_70caausx8bFuupIEZkfh/view?usp=sharing). Он похож на файл из предыдущего упражнения, но на этот раз мы не масштабировали непрерывные признаки (мы больше не будем использовать logreg).
# 2. Используя `train_test_split` с параметрами `test_size=0.2`, `random_state=21`, получаем `X_train`, `y_train`, `X_test`, `y_test`. Используйте дополнительный параметр `stratify`.

# %%
df = pd.read_csv('../data/day-of-week-not-scaled.csv')
df2 = pd.read_csv('../data/dayofweek.csv')
df['dayofweek'] = df2['dayofweek']

x = df.drop(['dayofweek'], axis=1)
y = df['dayofweek']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=21, stratify=y)

# %% [markdown]
# ## 2. SVM gridsearch

# %% [markdown]
# 1. Используя `GridSearchCV`, попробуйте различные параметры ядра (`linear`, `rbf`, `sigmoid`), C (`0.01`, `0.1`, `1`, `1.5`, `5`, `10`), gamma (`scale`, `auto`), class_weight (`balanced`, `None`), используйте `random_state=21` и `probability=True` и получите наилучшую комбинацию из них с точки зрения точности.
# 2. Создайте фрейм данных из результатов gridsearch и отсортируйте его по возрастанию по `rank_test_score`. Проверьте, велика ли разница между различными комбинациями (иногда более простая модель может дать сопоставимый результат).

# %%
model = SVC(random_state=21, probability=True)

param_grid = {'kernel': ['linear', 'rbf', 'sigmoid'],
            'C': [0.01, 0.1, 1, 1.5, 5, 10],
            'gamma': ['scale', 'auto'],
            'class_weight': ['balanced', None]}

gscv = GridSearchCV(estimator=model,
                    param_grid=param_grid,
                    scoring='accuracy',
                    n_jobs=-1)
gscv.fit(x_train, y_train)

print(f'Best params {gscv.best_params_}')
print(f'Best score {gscv.best_score_}')

params = pd.DataFrame(gscv.cv_results_)
params = params.sort_values('rank_test_score', ascending=True)
params
# Out:
# Best params {'C': 10, 'class_weight': None, 'gamma': 'auto', 'kernel': 'rbf'}
# Best score 0.8761090458488228
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 70       0.579127      0.004651         0.033142        0.000919     10.0
# 64       0.582633      0.005475         0.032866        0.000299     10.0
# 58       0.571245      0.033564         0.036928        0.002434      5.0
# 52       0.633290      0.053589         0.040646        0.003659      5.0
# 60      49.768416      4.199656         0.009930        0.000610     10.0
# ..            ...           ...              ...             ...      ...
# 53       0.665772      0.056007         0.020738        0.000825      5.0
# 65       0.583730      0.012254         0.019202        0.000540     10.0
# 41       0.693456      0.007474         0.019468        0.000254      1.5
# 17       0.764722      0.052643         0.026423        0.010738      0.1
# 29       0.727684      0.029875         0.020800        0.001521      1.0
#
#    param_class_weight param_gamma param_kernel  \
# 70               None        auto          rbf
# 64           balanced        auto          rbf
# 58               None        auto          rbf
# 52           balanced        auto          rbf
# 60           balanced       scale       linear
# ..                ...         ...          ...
# 53           balanced        auto      sigmoid
# 65           balanced        auto      sigmoid
# 41           balanced        auto      sigmoid
# 17           balanced        auto      sigmoid
# 29           balanced        auto      sigmoid
#
#                                                params  split0_test_score  \
# 70  {'C': 10, 'class_weight': None, 'gamma': 'auto...           0.900000
# 64  {'C': 10, 'class_weight': 'balanced', 'gamma':...           0.877778
# 58  {'C': 5, 'class_weight': None, 'gamma': 'auto'...           0.825926
# 52  {'C': 5, 'class_weight': 'balanced', 'gamma': ...           0.844444
# 60  {'C': 10, 'class_weight': 'balanced', 'gamma':...           0.729630
# ..                                                ...                ...
# 53  {'C': 5, 'class_weight': 'balanced', 'gamma': ...           0.144444
# 65  {'C': 10, 'class_weight': 'balanced', 'gamma':...           0.122222
# 41  {'C': 1.5, 'class_weight': 'balanced', 'gamma'...           0.066667
# 17  {'C': 0.1, 'class_weight': 'balanced', 'gamma'...           0.062963
# 29  {'C': 1, 'class_weight': 'balanced', 'gamma': ...           0.066667
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 70           0.848148           0.885185           0.884758
# 64           0.851852           0.862963           0.873606
# 58           0.811111           0.818519           0.821561
# 52           0.785185           0.792593           0.817844
# 60           0.700000           0.755556           0.754647
# ..                ...                ...                ...
# 53           0.148148           0.137037           0.126394
# 65           0.140741           0.129630           0.100372
# 41           0.085185           0.081481           0.078067
# 17           0.066667           0.062963           0.059480
# 29           0.070370           0.044444           0.063197
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 70           0.862454         0.876109        0.018419                1
# 64           0.851301         0.863500        0.010870                2
# 58           0.802974         0.816018        0.008116                3
# 52           0.802974         0.808608        0.021007                4
# 60           0.665428         0.721052        0.034438                5
# ..                ...              ...             ...              ...
# 53           0.092937         0.129792        0.019869               68
# 65           0.085502         0.115693        0.020052               69
# 41           0.085502         0.079380        0.006913               70
# 17           0.059480         0.062310        0.002678               71
# 29           0.055762         0.060088        0.009188               72
#
# [72 rows x 17 columns]

# %% [markdown]
# ## 3. Decision tree

# %% [markdown]
# 1. Используя `GridSearchCV`, попробуйте различные параметры `max_depth` (от `1` до `49`), `class_weight` (`balanced`, `None`) и `criterion` (`entropy` и `gini`) и получите наилучшую комбинацию из них с точки зрения точности. Используйте `random_state=21`.
# 2. Создайте кадр данных из результатов gridsearch и отсортируйте его по возрастанию по `rank_test_score`, проверьте, есть ли большая разница между различными комбинациями (иногда более простая модель может дать сопоставимый результат).

# %%
model = DecisionTreeClassifier(random_state=21)

param_grid = {'max_depth': np.arange(1, 49, 1),
                'class_weight': ['balanced', None],
                'criterion': ['entropy', 'gini']}

gscv = GridSearchCV(estimator=model,
                    param_grid=param_grid,
                    scoring='accuracy',
                    n_jobs=-1)
gscv.fit(x_train, y_train)

print(f'Best params {gscv.best_params_}')
print(f'Best score {gscv.best_score_}')

params = pd.DataFrame(gscv.cv_results_)
params = params.sort_values('rank_test_score', ascending=True)
params
# Out:
# Best params {'class_weight': 'balanced', 'criterion': 'gini', 'max_depth': np.int64(22)}
# Best score 0.8731212997384002
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 69        0.007110      0.000568         0.002318        0.000117
# 68        0.007086      0.000714         0.002315        0.000173
# 80        0.007002      0.000273         0.002473        0.000210
# 81        0.007280      0.000482         0.002313        0.000064
# 84        0.008235      0.002590         0.002442        0.000548
# ..             ...           ...              ...             ...
# 50        0.005102      0.000741         0.002922        0.000735
# 96        0.003809      0.000488         0.002414        0.000324
# 144       0.003579      0.000261         0.002408        0.000251
# 0         0.005176      0.000555         0.002571        0.000561
# 48        0.003684      0.000097         0.002121        0.000112
#
#     param_class_weight param_criterion  param_max_depth  \
# 69            balanced            gini               22
# 68            balanced            gini               21
# 80            balanced            gini               33
# 81            balanced            gini               34
# 84            balanced            gini               37
# ..                 ...             ...              ...
# 50            balanced            gini                3
# 96                None         entropy                1
# 144               None            gini                1
# 0             balanced         entropy                1
# 48            balanced            gini                1
#
#                                                 params  split0_test_score  \
# 69   {'class_weight': 'balanced', 'criterion': 'gin...           0.885185
# 68   {'class_weight': 'balanced', 'criterion': 'gin...           0.888889
# 80   {'class_weight': 'balanced', 'criterion': 'gin...           0.888889
# 81   {'class_weight': 'balanced', 'criterion': 'gin...           0.888889
# 84   {'class_weight': 'balanced', 'criterion': 'gin...           0.888889
# ..                                                 ...                ...
# 50   {'class_weight': 'balanced', 'criterion': 'gin...           0.388889
# 96   {'class_weight': None, 'criterion': 'entropy',...           0.370370
# 144  {'class_weight': None, 'criterion': 'gini', 'm...           0.370370
# 0    {'class_weight': 'balanced', 'criterion': 'ent...           0.262963
# 48   {'class_weight': 'balanced', 'criterion': 'gin...           0.262963
#
#      split1_test_score  split2_test_score  split3_test_score  \
# 69            0.862963           0.903704           0.881041
# 68            0.859259           0.903704           0.884758
# 80            0.866667           0.903704           0.873606
# 81            0.866667           0.903704           0.873606
# 84            0.866667           0.903704           0.873606
# ..                 ...                ...                ...
# 50            0.303704           0.403704           0.427509
# 96            0.351852           0.359259           0.353160
# 144           0.351852           0.359259           0.353160
# 0             0.318519           0.266667           0.323420
# 48            0.318519           0.266667           0.323420
#
#      split4_test_score  mean_test_score  std_test_score  rank_test_score
# 69            0.832714         0.873121        0.023998                1
# 68            0.828996         0.873121        0.026300                2
# 80            0.832714         0.873116        0.023911                3
# 81            0.832714         0.873116        0.023911                3
# 84            0.832714         0.873116        0.023911                3
# ..                 ...              ...             ...              ...
# 50            0.345725         0.373906        0.044064              188
# 96            0.342007         0.355330        0.009338              189
# 144           0.342007         0.355330        0.009338              189
# 0             0.260223         0.286358        0.028376              191
# 48            0.260223         0.286358        0.028376              191
#
# [192 rows x 16 columns]

# %% [markdown]
# ## 4. Random forest

# %% [markdown]
# 1. Используя `GridSearchCV`, попробуйте различные параметры `n_estimators` (`5`, `10`, `50`, `100`), `max_depth` (от `1` до `49`), `class_weight` (`balanced`, `None`) и `criterion` (`entropy` и `gini`) и получите наилучшую комбинацию из них с точки зрения точности. Используйте random_state=21.
# 2. Создайте кадр данных из результатов gridsearch и отсортируйте его по возрастанию по `rank_test_score`, проверьте, есть ли большая разница между различными комбинациями (иногда более простая модель может дать сопоставимый результат).

# %%
model = RandomForestClassifier(random_state=21)

param_grid = {'n_estimators': [5, 10, 50, 100],
                'max_depth': np.arange(1, 49, 1),
                'class_weight': ['balanced', None],
                'criterion': ['entropy', 'gini']}

gscv = GridSearchCV(estimator=model,
                    param_grid=param_grid,
                    scoring='accuracy',
                    n_jobs=-1)
gscv.fit(x_train, y_train)

print(f'Best params {gscv.best_params_}')
print(f'Best score {gscv.best_score_}')

params = pd.DataFrame(gscv.cv_results_)
params = params.sort_values('rank_test_score', ascending=True)
params
# Out:
# Best params {'class_weight': None, 'criterion': 'gini', 'max_depth': np.int64(28), 'n_estimators': 50}
# Best score 0.9042902381935839
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 686       0.139923      0.014801         0.010443        0.001515
# 699       0.277447      0.019353         0.015236        0.000752
# 310       0.127478      0.005379         0.008585        0.000095
# 326       0.129620      0.001969         0.009392        0.001230
# 727       0.301143      0.028789         0.016234        0.000348
# ..             ...           ...              ...             ...
# 384       0.012225      0.001106         0.002936        0.000037
# 4         0.012045      0.000279         0.003001        0.000116
# 196       0.012033      0.000258         0.002902        0.000013
# 192       0.013408      0.001598         0.003104        0.000182
# 0         0.012523      0.000388         0.003138        0.000070
#
#     param_class_weight param_criterion  param_max_depth  param_n_estimators  \
# 686               None            gini               28                  50
# 699               None            gini               31                 100
# 310           balanced            gini               30                  50
# 326           balanced            gini               34                  50
# 727               None            gini               38                 100
# ..                 ...             ...              ...                 ...
# 384               None         entropy                1                   5
# 4             balanced         entropy                2                   5
# 196           balanced            gini                2                   5
# 192           balanced            gini                1                   5
# 0             balanced         entropy                1                   5
#
#                                                 params  split0_test_score  \
# 686  {'class_weight': None, 'criterion': 'gini', 'm...           0.922222
# 699  {'class_weight': None, 'criterion': 'gini', 'm...           0.918519
# 310  {'class_weight': 'balanced', 'criterion': 'gin...           0.922222
# 326  {'class_weight': 'balanced', 'criterion': 'gin...           0.922222
# 727  {'class_weight': None, 'criterion': 'gini', 'm...           0.914815
# ..                                                 ...                ...
# 384  {'class_weight': None, 'criterion': 'entropy',...           0.355556
# 4    {'class_weight': 'balanced', 'criterion': 'ent...           0.318519
# 196  {'class_weight': 'balanced', 'criterion': 'gin...           0.311111
# 192  {'class_weight': 'balanced', 'criterion': 'gin...           0.262963
# 0    {'class_weight': 'balanced', 'criterion': 'ent...           0.262963
#
#      split1_test_score  split2_test_score  split3_test_score  \
# 686           0.900000           0.907407           0.903346
# 699           0.911111           0.900000           0.910781
# 310           0.907407           0.881481           0.907063
# 326           0.907407           0.892593           0.907063
# 727           0.911111           0.900000           0.903346
# ..                 ...                ...                ...
# 384           0.366667           0.374074           0.345725
# 4             0.366667           0.381481           0.353160
# 196           0.377778           0.377778           0.353160
# 192           0.292593           0.285185           0.282528
# 0             0.292593           0.225926           0.282528
#
#      split4_test_score  mean_test_score  std_test_score  rank_test_score
# 686           0.888476         0.904290        0.010961                1
# 699           0.877323         0.903547        0.014380                2
# 310           0.895911         0.902817        0.013554                3
# 326           0.884758         0.902809        0.013010                4
# 727           0.884758         0.902806        0.010460                5
# ..                 ...              ...             ...              ...
# 384           0.327138         0.353832        0.016467              764
# 4             0.345725         0.353110        0.021165              765
# 196           0.312268         0.346419        0.029749              766
# 192           0.293680         0.283390        0.011062              767
# 0             0.289963         0.270794        0.024718              768
#
# [768 rows x 17 columns]

# %% [markdown]
# ## 5. Progress bar

# %% [markdown]
# Поиск решетки может быть довольно долгим процессом, и вы можете задаться вопросом, когда же он закончится.
# 1. Создайте ручной gridsearch для тех же значений параметров random forest, итерируя список возможных значений и вычисляя `cross_val_score` для каждой комбинации. Попробуйте увеличить `n_jobs`. Значение `cv` для `cross_val_score` равно 5.
# 2. Отслеживайте прогресс, используя библиотеку `tqdm.notebook`.
# 3. Создайте фрейм данных из результатов gridsearch со столбцами, соответствующими названиям параметров, а также `mean_accuracy` и `std_accuracy`.
# 4. Отсортируйте его по убыванию `mean_accuracy`, проверьте, есть ли большая разница между различными комбинациями (иногда более простая модель может дать сопоставимый результат).

# %%
def gridsearch(param_grid, model_class):
    grid = list(ParameterGrid(param_grid))
    result = pd.DataFrame()

    for params in tqdm(grid):
        row = {}
        model = model_class(**params)
        score = cross_val_score(model, x_train, y_train, cv=5, n_jobs=-1)
        row = {**params, 'mean_accuracy': np.mean(score), 'std_accuracy': np.std(score)}
        result = pd.concat([result, pd.DataFrame([row])], ignore_index=True)

    result = result.sort_values('mean_accuracy', ascending=False)
    return result

# %%
model = RandomForestClassifier
param_grid = {'n_estimators': [5, 10, 50, 100],
                'max_depth': np.arange(1, 49, 1),
                'class_weight': ['balanced', None],
                'criterion': ['entropy', 'gini'],
                'random_state': [21]}

result = gridsearch(param_grid, model)
result
# Out:
#   0%|          | 0/768 [00:00<?, ?it/s]
#     class_weight criterion  max_depth  n_estimators  random_state  \
# 686         None      gini         28            50            21
# 699         None      gini         31           100            21
# 310     balanced      gini         30            50            21
# 326     balanced      gini         34            50            21
# 751         None      gini         44           100            21
# ..           ...       ...        ...           ...           ...
# 384         None   entropy          1             5            21
# 4       balanced   entropy          2             5            21
# 196     balanced      gini          2             5            21
# 192     balanced      gini          1             5            21
# 0       balanced   entropy          1             5            21
#
#      mean_accuracy  std_accuracy
# 686       0.904290      0.010961
# 699       0.903547      0.014380
# 310       0.902817      0.013554
# 326       0.902809      0.013010
# 751       0.902806      0.010460
# ..             ...           ...
# 384       0.353832      0.016467
# 4         0.353110      0.021165
# 196       0.346419      0.029749
# 192       0.283390      0.011062
# 0         0.270794      0.024718
#
# [768 rows x 7 columns]

# %% [markdown]
# ## 6. Predictions

# %% [markdown]
# 1. Выберите лучшую модель и используйте ее для прогнозирования тестового набора данных.
# 2. Рассчитайте итоговую точность.

# %%
best_params = {'class_weight': None, 'criterion': 'gini', 'max_depth': np.int64(28), 'n_estimators': 50}
model = RandomForestClassifier(random_state=21, **best_params)
model.fit(x_train, y_train)
print(f'Accuracy = {accuracy_score(y_test, model.predict(x_test))}')
# Out:
# Accuracy = 0.9289940828402367
